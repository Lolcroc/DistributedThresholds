# %%
from manticore.geometry.library import CubicCell, DiamondCell, DoubleEdgeCubicCell, TriamondCell

use_pre_calculated_data = True # Use pre-calculated data to generate the plots
numb_MC_iterations = 16        # Number of Monte Carlo iterations (for the pre-calculated data, 50000 is used)

# %% [markdown]
# # Figure 7
# ### Calculating the data for Fig. 7

# %%
if not use_pre_calculated_data:
    from manticore.experiments.library import PhenomErasureThreshold
    paths_main = []
    paths_compare = []
    paths_main.append(PhenomErasureThreshold(CubicCell(), 0.02, 0.035, 0.22, 0.255, 7, 28, numb_MC_iterations, sizes=[5, 7, 9, 11], boundary=False).run_experiment().to_json())
    paths_main.append(PhenomErasureThreshold(DiamondCell(), 0.045, 0.06, 0.365, 0.4, 7, 28, numb_MC_iterations, sizes=[5, 7, 9, 11], boundary=False).run_experiment().to_json())
    paths_main.append(PhenomErasureThreshold(DoubleEdgeCubicCell(), 0.07, 0.09, 0.48, 0.505, 7, 28, numb_MC_iterations, sizes=[5, 7, 9, 11], boundary=False).run_experiment().to_json())
    paths_main.append(PhenomErasureThreshold(TriamondCell(), 0.085, 0.11, 0.525, 0.56, 7, 28, numb_MC_iterations, sizes=[5, 7, 9, 11], boundary=False).run_experiment().to_json())
    paths_compare.append(PhenomErasureThreshold(CubicCell(), 0.02, 0.035, 0.22, 0.255, 7, 28, numb_MC_iterations, sizes=[5, 7, 9, 11], boundary=True).run_experiment().to_json())
    paths_compare.append(PhenomErasureThreshold(DiamondCell(), 0.045, 0.06, 0.365, 0.4, 7, 28, numb_MC_iterations, sizes=[5, 7, 9, 11], boundary=True).run_experiment().to_json())
    paths_compare.append(PhenomErasureThreshold(DoubleEdgeCubicCell(), 0.07, 0.09, 0.48, 0.505, 7, 28, numb_MC_iterations, sizes=[5, 7, 9, 11], boundary=True).run_experiment().to_json())
    paths_compare.append(PhenomErasureThreshold(TriamondCell(), 0.085, 0.11, 0.525, 0.56, 7, 28, numb_MC_iterations, sizes=[5, 7, 9, 11], boundary=True).run_experiment().to_json())
else:
    paths_main = None
    paths_compare = None

# %% [markdown]
# ### Plotting Fig. 7
# If we do not pass any arguments, the function will use default (i.e., pre-calculated) data:

# %%
from generate_figures import plot_fault_tolerant_region_phenomenological_vs_erasure

paths_main, paths_compare, names, phenom_thresholds, phenom_errs, erasure_thresholds, erasure_errs, \
phenom_diff, phenom_diff_err, \
erasure_diff, erasure_diff_err = plot_fault_tolerant_region_phenomenological_vs_erasure(paths_main, paths_compare, order=2)

# %%
from generate_figures import plot_thresholds_phenomenological_vs_erasure

for path in paths_main + paths_compare:
    if "threshold_cubic" in path: # and "boundary" not in path:
        plot_thresholds_phenomenological_vs_erasure(path, order=2)

# %% [markdown]
# # Figure 8
# ### Calculating the data for Fig. 8

# %%
if not use_pre_calculated_data:
    from manticore.experiments.library import PhenomErasureThreshold
    paths_no_boundary = []
    paths_boundary = []
    paths_no_boundary.append(PhenomErasureThreshold(CubicCell(), 0.02, 0.025, 0.21, 0.24, 4, 16, numb_MC_iterations, sizes=[5, 7, 9, 11], boundary=False).run_experiment().to_json())
    paths_boundary.append(PhenomErasureThreshold(CubicCell(), 0.02, 0.025, 0.21, 0.24, 4, 16, numb_MC_iterations, sizes=[5, 7, 9, 11], boundary=True).run_experiment().to_json())
    paths_no_boundary.append(PhenomErasureThreshold(DiamondCell(), 0.045, 0.052, 0.35, 0.375, 4, 16, numb_MC_iterations, sizes=[5, 7, 9, 11], boundary=False).run_experiment().to_json())
    paths_boundary.append(PhenomErasureThreshold(DiamondCell(), 0.045, 0.052, 0.35, 0.375, 4, 16, numb_MC_iterations, sizes=[5, 7, 9, 11], boundary=True).run_experiment().to_json())
    paths_no_boundary.append(PhenomErasureThreshold(DoubleEdgeCubicCell(), 0.07, 0.08, 0.46, 0.49, 4, 16, numb_MC_iterations, sizes=[5, 7, 9, 11], boundary=False).run_experiment().to_json())
    paths_boundary.append(PhenomErasureThreshold(DoubleEdgeCubicCell(), 0.07, 0.08, 0.46, 0.49, 4, 16, numb_MC_iterations, sizes=[5, 7, 9, 11], boundary=True).run_experiment().to_json())
    paths_no_boundary.append(PhenomErasureThreshold(TriamondCell(), 0.085, 0.098, 0.51, 0.54, 4, 16, numb_MC_iterations, sizes=[5, 7, 9, 11], boundary=False).run_experiment().to_json())
    paths_boundary.append(PhenomErasureThreshold(TriamondCell(), 0.085, 0.098, 0.51, 0.54, 4, 16, numb_MC_iterations, sizes=[5, 7, 9, 11], boundary=True).run_experiment().to_json())
else:
    paths_no_boundary = None
    paths_boundary = None

# %% [markdown]
# ### Plotting Fig. 8
# If we do not pass any arguments, the function will use default (i.e., pre-calculated) data:

# %%
from generate_figures import plot_subthreshold_scaling_boundaries

plot_subthreshold_scaling_boundaries(paths_no_boundary, paths_boundary)

# %% [markdown]
# # Figure 9
# ### Calculating the data for Fig. 9

# %%
from manticore.experiments.monolithic import MonolithicThreshold

if not use_pre_calculated_data:
    paths = []
    paths.append(MonolithicThreshold(CubicCell(), 0.0035, 0.0055, num_p=7, num_shots=numb_MC_iterations, sizes=[5, 7, 9, 11]).run_experiment().to_json())
    paths.append(MonolithicThreshold(CubicCell(), 0.0035, 0.0055, num_p=7, num_shots=numb_MC_iterations, sizes=[5, 7, 9, 11], color_ordering=[0, 2, 1, 3]).run_experiment().to_json())
    paths.append(MonolithicThreshold(DoubleEdgeCubicCell(), 0.002, 0.0032, num_p=7, num_shots=numb_MC_iterations, sizes=[5, 7, 9, 11]).run_experiment().to_json())
    paths.append(MonolithicThreshold(DiamondCell(), 0.0039, 0.0059, num_p=7, num_shots=numb_MC_iterations, sizes=[5, 7, 9, 11]).run_experiment().to_json())
    paths.append(MonolithicThreshold(DiamondCell(), 0.0042, 0.0062, num_p=7, num_shots=numb_MC_iterations, sizes=[5, 7, 9, 11], color_ordering=[0, 2, 4, 1, 3, 5]).run_experiment().to_json())
    paths.append(MonolithicThreshold(TriamondCell(), 0.0028, 0.0048, num_p=7, num_shots=numb_MC_iterations, sizes=[5, 7, 9, 11]).run_experiment().to_json())
    paths.append(MonolithicThreshold(DiamondCell(), 0.0053, 0.0073, num_p=7, num_shots=numb_MC_iterations, sizes=[5, 7, 9, 11], color_ordering=[0, 3, 1, 4, 2, 5]).run_experiment().to_json())
    paths.append(MonolithicThreshold(DoubleEdgeCubicCell(), 0.0018, 0.0038, num_p=7, num_shots=numb_MC_iterations, sizes=[5, 7, 9, 11], color_ordering=[0, 2, 4, 6, 1, 3, 5, 7]).run_experiment().to_json())
    paths.append(MonolithicThreshold(DoubleEdgeCubicCell(), 0.0028, 0.0048, num_p=7, num_shots=numb_MC_iterations, sizes=[5, 7, 9, 11], color_ordering=[0, 4, 1, 5, 2, 6, 3, 7]).run_experiment().to_json())
    names_mono = ["cubic", "cubic", "d.e. cubic", "diamond", "diamond", "triamond", "diamond", "d.e. cubic", "d.e. cubic"]
    orderings_mono = ["", "0231", "", "", "024135", "", "031425", "02461357", "04152637"]
else:
    paths = None
    names_mono = None
    orderings_mono = None

# %% [markdown]
# ### Plotting Fig. 9
# If we do not pass any arguments, the function will use default (i.e., pre-calculated) data:

# %%
from generate_figures import plot_monolithic_thresholds

monolithic_thresholds, monolithic_errors = plot_monolithic_thresholds(paths, names_mono, orderings_mono, order=2)

# %% [markdown]
# # Figure 11
# ### Calculating the data for Fig. 11

# %%
if not use_pre_calculated_data:
    from manticore.experiments.distributed import SixRingThreshold, CubicGHZFusionThreshold, ThreeDiamondFusionThreshold, \
        TwoThreeDiamondFusionThreshold, DoubleEdgeBellThreshold, DoubleEdgeGHZFusionThreshold
    paths_dist = []
    paths_dist.append(CubicGHZFusionThreshold(num_shots=numb_MC_iterations, resolution=7, sizes=[5, 7, 9, 11], p=(0.0025, 0.0035), p_i=(0.008, 0.012)).run_experiment().to_json())
    paths_dist.append(SixRingThreshold(num_shots=numb_MC_iterations, resolution=7, sizes=[5, 7, 9, 11], p=(0.003, 0.006), p_i=(0.008, 0.012)).run_experiment().to_json())
    paths_dist.append(ThreeDiamondFusionThreshold(num_shots=numb_MC_iterations, resolution=7, sizes=[5, 7, 9, 11], p=(0.004, 0.006), p_i=(0.015, 0.025)).run_experiment().to_json())
    paths_dist.append(TwoThreeDiamondFusionThreshold(num_shots=numb_MC_iterations, resolution=7, sizes=[5, 7, 9, 11], p=(0.005, 0.007), p_i=(0.02, 0.025)).run_experiment().to_json())
    paths_dist.append(DoubleEdgeBellThreshold(num_shots=numb_MC_iterations, resolution=7, sizes=[5, 7, 9, 11], p=(0.002, 0.003), p_i=(0.004, 0.007)).run_experiment().to_json())
    paths_dist.append(DoubleEdgeGHZFusionThreshold(num_shots=numb_MC_iterations, resolution=7, sizes=[5, 7, 9, 11], p=(0.004, 0.005), p_i=(0.012, 0.017)).run_experiment().to_json())
    names_dist = ["2-node", "6-ring", "4-ring", "7-node", "12-node", "4-ring"]
else:
    paths_dist = None
    names_dist = ["2-node", "6-ring", "4-ring", "7-node", "12-node", "4-ring"]

# %% [markdown]
# ### Plotting Fig. 11
# If we do not pass any arguments, the function will use default (i.e., pre-calculated) data:

# %%
from generate_figures import plot_fault_tolerant_region_distributed

paths_dist, network_thresholds, network_errors, circuit_thresholds, circuit_errors = plot_fault_tolerant_region_distributed(paths_dist, names_dist, order=2)

# %%
from generate_figures import plot_thresholds_phenomenological_vs_erasure

for path in paths_dist:
    if "threshold_double_edge_cubic" in path: # and "ghz_fusion" in path:
        plot_thresholds_phenomenological_vs_erasure(path, order=2, threshold_param="t", size_param="s", phys_params=("c_p_i","c_p"))

# %% [markdown]
# # Figure 12
# ### Calculating the data for Fig. 12

# %%
if not use_pre_calculated_data:
    from manticore.experiments.distributed import SixRingErasureThreshold
    path1 = SixRingErasureThreshold(num_shots=numb_MC_iterations, resolution=7, sizes=[5, 7, 9, 11], p=(0.2, 0.3), p_i=(0.008, 0.012)).run_experiment().to_json()
else:
    path1 = None

# %% [markdown]
# ### Plotting Fig. 12
# If we do not pass any arguments, the function will use default (i.e., pre-calculated) data:

# %%
from generate_figures import plot_trade_off_network_error_erasure

path1 = plot_trade_off_network_error_erasure(path1, order=2)

# %% [markdown]
# # Figure 6
# ### Plotting Fig. 6
# If we do not pass any arguments, the function will use default (i.e., pre-calculated) data:

# %%
from generate_figures import overview_figure_thresholds

overview_figure_thresholds(
    names=names,
    phenom_thresholds=phenom_thresholds,
    phenom_errors=phenom_errs,
    erasure_thresholds=erasure_thresholds,
    erasure_errors=erasure_errs,
    phenom_boundary_diffs=phenom_diff,
    phenom_boundary_errors=phenom_diff_err,
    erasure_boundary_diffs=erasure_diff,
    erasure_boundary_errors=erasure_diff_err,
    monolithic_thresholds=monolithic_thresholds,
    monolithic_errors=monolithic_errors,
    distributed_names=names_dist,
    network_thresholds=network_thresholds,
    network_errors=network_errors,
    circuit_thresholds=circuit_thresholds,
    circuit_errors=circuit_errors,
)
